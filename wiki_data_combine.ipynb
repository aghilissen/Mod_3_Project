# %% [markdown]
# # Wikipedia Data Merging

# %% [markdown]
# In this Jupyter Notebook, we verify the data webscraped from Wikipedia (see the [data](./data) folder). We'll check the individual .csv files and make sure we can merged them in a main datafile.

# %% [markdown]
# ## Section 0 - Setting up the environment
# Importing libraries, files and define functions

# %%
import pandas as pd

# %%
df_happiness = pd.read_csv('./data/happiness.csv')
df_happiness.set_index('countries', inplace = True);
df_happiness.drop(df_happiness.columns[0], axis=1, inplace = True);
# Our initial DataFrame, we'll left-inner-join the other data source to this one,
# index following the 'countries' column (we didn't know about the 'index_col=0' option at the time =)

# %%
country_rename_dict = {"China, People's Republic of" : "China",
                       "Cote d'Ivoire": "Ivory Coast",
                       "Côte d'Ivoire": "Ivory Coast",
                       "People's Republic of China": "China",
                       'Burma': 'Myanmar',
                       'Congo': 'Congo (Brazzaville)',
                       'Congo, Democratic Republic of the': 'Congo (Kinshasa)',
                       'Congo, Republic of the': 'Congo (Brazzaville)',
                       'Congo, Republic of': 'Congo (Brazzaville)',
                       'Czech Republic': 'Czechia',
                       'Democratic Republic of Congo': 'Congo (Kinshasa)',
                       'Democratic Republic of the Congo': 'Congo (Kinshasa)',
                       'DR Congo': 'Congo (Kinshasa)',
                       'Eswatini (Swaziland)': 'Eswatini',
                       'Gambia, The': 'Gambia',
                       'Great Britain': 'United Kingdom',
                       'Korea, North': 'North Korea',
                       'Korea, South': 'South Korea',
                       'Republic of the Congo': 'Congo (Brazzaville)',
                       'Swaziland': 'Eswatini',
                       'The Gambia' : 'Gambia',
                       'Trinidad and Tobago': 'Trinidad & Tobago',
                       'United States': 'United States of America'
                      }
# this dictionary will be used to bring the different country name styles to a common denominator

# %%
def rename_country(country_name):
    """
    Renames the country name to the default spelling, as in the happiness DataFrame. 
    
    Arguments: 
    country_name -- name of the country to check and see if it's an alternative spelling
    
    Returns: 
    default spelling of country name (could be the same as input)
    """
    
    if country_name in country_rename_dict.keys():
        return country_rename_dict[country_name]
    else:
        return country_name

# %%
def make_mergeable(df):
    """
    Prepares a DataFrame to be merged with the happiness DataFrame.
    
    Arguments:
    df -- DataFrame to be prepared, assumed to contain a 'countries' column
    
    Returns:
    df -- the modified DataFrame, with countries changed to default spelling, 
    index set to countries column
    """
    
    df['countries'] = df['countries'].apply(lambda x: rename_country(x));
    # renames countries in line with the happiness index

    df.set_index('countries', inplace = True);
    df.drop(df.columns[0], axis=1, inplace = True);
    # resets index to countries
    
    return df

# %%
def merge_with_happiness(df):
    """
    Left inner join to the happiness DataFrame
    
    Arguments:
    df --DataFrame to merge with happiness
    
    Returns:
    happiness DataFrame with the added data issued from 'df'
    """
    
    return df_happiness.join(df, how = 'left')

# %%
def merge_and_check_empty(csv_filename, new_column_label):
    """
    Recurring function used to check the elements which are in the happiness DataFrame
    but not in the new DataFrame we want to merge it with. 
    
    Arguments: 
    csv_filename -- filename of the file we want to merge with happiness
    new_column_label -- column in the new DataFrame we will check for empty data
    
    Returns: 
    the combined DataFrame filtered down to rows where the new DataFrame had 
    missing elements
    """
    
    df = pd.read_csv(csv_filename)
    df = make_mergeable(df)
    df_combined = df_happiness.join(df, how = 'left')
    return df_combined[df_combined[new_column_label].isnull()]

# %% [markdown]
# ## Section 1 - Individual Data Merging Analysis

# %% [markdown]
# In this section, we merge the different .csv files with the happiness file by countries, and check for missing data. We used this process to build up the *country_rename_dict*, the dictionary containing the alternative and default spellings of specific countries.

# %% [markdown]
# ### alcohol_consumption.csv

# %%
merge_and_check_empty('./data/alcohol_consumption.csv', 'alcohol_consumption')
# Out:
#                          happiness  GDP_per_capita  social_support  \
# countries
# Taiwan                       6.446           1.368           1.430
# Kosovo                       6.100           0.882           1.232
# Northern Cyprus              5.718           1.263           1.252
# Hong Kong                    5.430           1.438           1.277
# Palestinian Territories      4.696           0.657           1.247
# South Sudan                  2.853           0.306           0.575
#
#                          healthy_life_exp  freedom  generosity  corruption  \
# countries
# Taiwan                              0.914    0.351       0.242       0.097
# Kosovo                              0.758    0.489       0.262       0.006
# Northern Cyprus                     1.042    0.417       0.191       0.162
# Hong Kong                           1.122    0.440       0.258       0.287
# Palestinian Territories             0.672    0.225       0.103       0.066
# South Sudan                         0.295    0.010       0.202       0.091
#
#                          alcohol_consumption
# countries
# Taiwan                                   NaN
# Kosovo                                   NaN
# Northern Cyprus                          NaN
# Hong Kong                                NaN
# Palestinian Territories                  NaN
# South Sudan                              NaN

# %% [markdown]
# ### cigarettes.csv

# %%
merge_and_check_empty('./data/cigarettes.csv', 'cigarette_consumption')
# Out:
#                          happiness  GDP_per_capita  social_support  \
# countries
# United Arab Emirates         6.825           1.503           1.310
# Taiwan                       6.446           1.368           1.430
# Kosovo                       6.100           0.882           1.232
# Northern Cyprus              5.718           1.263           1.252
# Hong Kong                    5.430           1.438           1.277
# Bhutan                       5.082           0.813           1.321
# Palestinian Territories      4.696           0.657           1.247
#
#                          healthy_life_exp  freedom  generosity  corruption  \
# countries
# United Arab Emirates                0.825    0.598       0.262       0.182
# Taiwan                              0.914    0.351       0.242       0.097
# Kosovo                              0.758    0.489       0.262       0.006
# Northern Cyprus                     1.042    0.417       0.191       0.162
# Hong Kong                           1.122    0.440       0.258       0.287
# Bhutan                              0.604    0.457       0.370       0.167
# Palestinian Territories             0.672    0.225       0.103       0.066
#
#                          cigarette_consumption
# countries
# United Arab Emirates                       NaN
# Taiwan                                     NaN
# Kosovo                                     NaN
# Northern Cyprus                            NaN
# Hong Kong                                  NaN
# Bhutan                                     NaN
# Palestinian Territories                    NaN

# %% [markdown]
# ### economic_sectors.csv

# %%
merge_and_check_empty('./data/economical_sectors.csv', 'agricultural')
# Out:
#                          happiness  GDP_per_capita  social_support  \
# countries
# Northern Cyprus              5.718           1.263           1.252
# Palestinian Territories      4.696           0.657           1.247
# South Sudan                  2.853           0.306           0.575
#
#                          healthy_life_exp  freedom  generosity  corruption  \
# countries
# Northern Cyprus                     1.042    0.417       0.191       0.162
# Palestinian Territories             0.672    0.225       0.103       0.066
# South Sudan                         0.295    0.010       0.202       0.091
#
#                         agricultural industrial service
# countries
# Northern Cyprus                  NaN        NaN     NaN
# Palestinian Territories          NaN        NaN     NaN
# South Sudan                      NaN        NaN     NaN

# %% [markdown]
# ### government_system.csv

# %%
merge_and_check_empty('./data/government_system.csv', 'const_form')
# Out:
#                          happiness  GDP_per_capita  social_support  \
# countries
# Taiwan                       6.446           1.368           1.430
# Kosovo                       6.100           0.882           1.232
# Northern Cyprus              5.718           1.263           1.252
# Libya                        5.525           1.044           1.303
# Hong Kong                    5.430           1.438           1.277
# Palestinian Territories      4.696           0.657           1.247
# Yemen                        3.380           0.287           1.163
#
#                          healthy_life_exp  freedom  generosity  corruption  \
# countries
# Taiwan                              0.914    0.351       0.242       0.097
# Kosovo                              0.758    0.489       0.262       0.006
# Northern Cyprus                     1.042    0.417       0.191       0.162
# Libya                               0.673    0.416       0.133       0.152
# Hong Kong                           1.122    0.440       0.258       0.287
# Palestinian Territories             0.672    0.225       0.103       0.066
# Yemen                               0.463    0.143       0.108       0.077
#
#                         const_form head_of_state
# countries
# Taiwan                         NaN           NaN
# Kosovo                         NaN           NaN
# Northern Cyprus                NaN           NaN
# Libya                          NaN           NaN
# Hong Kong                      NaN           NaN
# Palestinian Territories        NaN           NaN
# Yemen                          NaN           NaN

# %% [markdown]
# Libya and Yemen are listed with an empty value, the other countries are not in this *government_system* list

# %% [markdown]
# ### median_age.csv

# %%
merge_and_check_empty('./data/median_age.csv', 'median_age')
# Out:
#                          happiness  GDP_per_capita  social_support  \
# countries
# Northern Cyprus              5.718           1.263           1.252
# Palestinian Territories      4.696           0.657           1.247
#
#                          healthy_life_exp  freedom  generosity  corruption  \
# countries
# Northern Cyprus                     1.042    0.417       0.191       0.162
# Palestinian Territories             0.672    0.225       0.103       0.066
#
#                          median_age  median_age_male  median_age_female
# countries
# Northern Cyprus                 NaN              NaN                NaN
# Palestinian Territories         NaN              NaN                NaN

# %% [markdown]
# ### olympic_medals_2016.csv

# %%
merge_and_check_empty('./data/olympic_medals_2016.csv', 'gold_medals_2016')
# Out:
#                           happiness  GDP_per_capita  social_support  \
# countries
# Iceland                       7.494           1.380           1.624
# Costa Rica                    7.167           1.034           1.441
# Luxembourg                    7.090           1.609           1.479
# Malta                         6.726           1.300           1.520
# Taiwan                        6.446           1.368           1.430
# ...                             ...             ...             ...
# Rwanda                        3.334           0.359           0.711
# Tanzania                      3.231           0.476           0.885
# Afghanistan                   3.203           0.350           0.517
# Central African Republic      3.083           0.026           0.000
# South Sudan                   2.853           0.306           0.575
#
#                           healthy_life_exp  freedom  generosity  corruption  \
# countries
# Iceland                              1.026    0.591       0.354       0.118
# Costa Rica                           0.963    0.558       0.144       0.093
# Luxembourg                           1.012    0.526       0.194       0.316
# Malta                                0.999    0.564       0.375       0.151
# Taiwan                               0.914    0.351       0.242       0.097
# ...                                    ...      ...         ...         ...
# Rwanda                               0.614    0.555       0.217       0.411
# Tanzania                             0.499    0.417       0.276       0.147
# Afghanistan                          0.361    0.000       0.158       0.025
# Central African Republic             0.105    0.225       0.235       0.035
# South Sudan                          0.295    0.010       0.202       0.091
#
#                           gold_medals_2016  silver_medals_2016  \
# countries
# Iceland                                NaN                 NaN
# Costa Rica                             NaN                 NaN
# Luxembourg                             NaN                 NaN
# Malta                                  NaN                 NaN
# Taiwan                                 NaN                 NaN
# ...                                    ...                 ...
# Rwanda                                 NaN                 NaN
# Tanzania                               NaN                 NaN
# Afghanistan                            NaN                 NaN
# Central African Republic               NaN                 NaN
# South Sudan                            NaN                 NaN
#
#                           bronze_medals_2016
# countries
# Iceland                                  NaN
# Costa Rica                               NaN
# Luxembourg                               NaN
# Malta                                    NaN
# Taiwan                                   NaN
# ...                                      ...
# Rwanda                                   NaN
# Tanzania                                 NaN
# Afghanistan                              NaN
# Central African Republic                 NaN
# South Sudan                              NaN
#
# [78 rows x 10 columns]

# %% [markdown]
# We will assume these empty values to be 0 in the [WB notebook](WB.ipynb)

# %% [markdown]
# ### oscar.csv

# %%
merge_and_check_empty('./data/oscar.csv', 'oscar_winning')
# Out:
#                           happiness  GDP_per_capita  social_support  \
# countries
# United States of America      6.892           1.433           1.457
# United Arab Emirates          6.825           1.503           1.310
# Qatar                         6.374           1.684           1.313
# El Salvador                   6.253           0.794           1.242
# Bahrain                       6.199           1.362           1.368
# Trinidad & Tobago             6.192           1.231           1.477
# Cyprus                        6.046           1.263           1.223
# Jamaica                       5.890           0.831           1.478
# Mauritius                     5.888           1.120           1.402
# Northern Cyprus               5.718           1.263           1.252
# Libya                         5.525           1.044           1.303
# Bosnia and Herzegovina        5.386           0.945           1.212
# Turkmenistan                  5.247           1.052           1.538
# Benin                         4.883           0.393           0.437
# Congo (Brazzaville)           4.812           0.673           0.799
# Gabon                         4.799           1.057           1.183
# Palestinian Territories       4.696           0.657           1.247
# Somalia                       4.668           0.000           0.698
# Namibia                       4.639           0.879           1.313
# Guinea                        4.534           0.380           0.829
# Gambia                        4.516           0.308           0.939
# Mali                          4.390           0.385           1.105
# Sierra Leone                  4.374           0.268           0.841
# Myanmar                       4.360           0.710           1.181
# Eswatini                      4.212           0.811           1.149
# Uganda                        4.189           0.332           1.069
# Zambia                        4.107           0.578           1.058
# Togo                          4.085           0.275           0.572
# Liberia                       3.975           0.073           0.922
# Comoros                       3.973           0.274           0.757
# Madagascar                    3.933           0.274           0.916
# Lesotho                       3.802           0.489           1.169
# Burundi                       3.775           0.046           0.447
# Zimbabwe                      3.663           0.366           1.114
# Botswana                      3.488           1.041           1.145
# Rwanda                        3.334           0.359           0.711
# Central African Republic      3.083           0.026           0.000
# South Sudan                   2.853           0.306           0.575
#
#                           healthy_life_exp  freedom  generosity  corruption  \
# countries
# United States of America             0.874    0.454       0.280       0.128
# United Arab Emirates                 0.825    0.598       0.262       0.182
# Qatar                                0.871    0.555       0.220       0.167
# El Salvador                          0.789    0.430       0.093       0.074
# Bahrain                              0.871    0.536       0.255       0.110
# Trinidad & Tobago                    0.713    0.489       0.185       0.016
# Cyprus                               1.042    0.406       0.190       0.041
# Jamaica                              0.831    0.490       0.107       0.028
# Mauritius                            0.798    0.498       0.215       0.060
# Northern Cyprus                      1.042    0.417       0.191       0.162
# Libya                                0.673    0.416       0.133       0.152
# Bosnia and Herzegovina               0.845    0.212       0.263       0.006
# Turkmenistan                         0.657    0.394       0.244       0.028
# Benin                                0.397    0.349       0.175       0.082
# Congo (Brazzaville)                  0.508    0.372       0.105       0.093
# Gabon                                0.571    0.295       0.043       0.055
# Palestinian Territories              0.672    0.225       0.103       0.066
# Somalia                              0.268    0.559       0.243       0.270
# Namibia                              0.477    0.401       0.070       0.056
# Guinea                               0.375    0.332       0.207       0.086
# Gambia                               0.428    0.382       0.269       0.167
# Mali                                 0.308    0.327       0.153       0.052
# Sierra Leone                         0.242    0.309       0.252       0.045
# Myanmar                              0.555    0.525       0.566       0.172
# Eswatini                             0.000    0.313       0.074       0.135
# Uganda                               0.443    0.356       0.252       0.060
# Zambia                               0.426    0.431       0.247       0.087
# Togo                                 0.410    0.293       0.177       0.085
# Liberia                              0.443    0.370       0.233       0.033
# Comoros                              0.505    0.142       0.275       0.078
# Madagascar                           0.555    0.148       0.169       0.041
# Lesotho                              0.168    0.359       0.107       0.093
# Burundi                              0.380    0.220       0.176       0.180
# Zimbabwe                             0.433    0.361       0.151       0.089
# Botswana                             0.538    0.455       0.025       0.100
# Rwanda                               0.614    0.555       0.217       0.411
# Central African Republic             0.105    0.225       0.235       0.035
# South Sudan                          0.295    0.010       0.202       0.091
#
#                           oscar_winning
# countries
# United States of America            NaN
# United Arab Emirates                NaN
# Qatar                               NaN
# El Salvador                         NaN
# Bahrain                             NaN
# Trinidad & Tobago                   NaN
# Cyprus                              NaN
# Jamaica                             NaN
# Mauritius                           NaN
# Northern Cyprus                     NaN
# Libya                               NaN
# Bosnia and Herzegovina              NaN
# Turkmenistan                        NaN
# Benin                               NaN
# Congo (Brazzaville)                 NaN
# Gabon                               NaN
# Palestinian Territories             NaN
# Somalia                             NaN
# Namibia                             NaN
# Guinea                              NaN
# Gambia                              NaN
# Mali                                NaN
# Sierra Leone                        NaN
# Myanmar                             NaN
# Eswatini                            NaN
# Uganda                              NaN
# Zambia                              NaN
# Togo                                NaN
# Liberia                             NaN
# Comoros                             NaN
# Madagascar                          NaN
# Lesotho                             NaN
# Burundi                             NaN
# Zimbabwe                            NaN
# Botswana                            NaN
# Rwanda                              NaN
# Central African Republic            NaN
# South Sudan                         NaN

# %% [markdown]
# Again, we will assume these empty values to be 0 in the [WB notebook](WB.ipynb)

# %% [markdown]
# ### railways.csv

# %%
merge_and_check_empty('./data/railways.csv', 'railways_per_capita')
# Out:
#                           happiness  GDP_per_capita  social_support  \
# countries
# Iceland                       7.494           1.380           1.624
# Malta                         6.726           1.300           1.520
# Qatar                         6.374           1.684           1.313
# Bahrain                       6.199           1.362           1.368
# Trinidad & Tobago             6.192           1.231           1.477
# Nicaragua                     6.105           0.694           1.325
# Kosovo                        6.100           0.882           1.232
# Cyprus                        6.046           1.263           1.223
# Kuwait                        6.021           1.500           1.319
# Mauritius                     5.888           1.120           1.402
# Northern Cyprus               5.718           1.263           1.252
# Libya                         5.525           1.044           1.303
# Lebanon                       5.197           0.987           1.224
# Bhutan                        5.082           0.813           1.321
# Palestinian Territories       4.696           0.657           1.247
# Somalia                       4.668           0.000           0.698
# Niger                         4.628           0.138           0.774
# Gambia                        4.516           0.308           0.939
# Chad                          4.350           0.350           0.766
# Comoros                       3.973           0.274           0.757
# Burundi                       3.775           0.046           0.447
# Haiti                         3.597           0.323           0.688
# Yemen                         3.380           0.287           1.163
# Rwanda                        3.334           0.359           0.711
# Central African Republic      3.083           0.026           0.000
# South Sudan                   2.853           0.306           0.575
#
#                           healthy_life_exp  freedom  generosity  corruption  \
# countries
# Iceland                              1.026    0.591       0.354       0.118
# Malta                                0.999    0.564       0.375       0.151
# Qatar                                0.871    0.555       0.220       0.167
# Bahrain                              0.871    0.536       0.255       0.110
# Trinidad & Tobago                    0.713    0.489       0.185       0.016
# Nicaragua                            0.835    0.435       0.200       0.127
# Kosovo                               0.758    0.489       0.262       0.006
# Cyprus                               1.042    0.406       0.190       0.041
# Kuwait                               0.808    0.493       0.142       0.097
# Mauritius                            0.798    0.498       0.215       0.060
# Northern Cyprus                      1.042    0.417       0.191       0.162
# Libya                                0.673    0.416       0.133       0.152
# Lebanon                              0.815    0.216       0.166       0.027
# Bhutan                               0.604    0.457       0.370       0.167
# Palestinian Territories              0.672    0.225       0.103       0.066
# Somalia                              0.268    0.559       0.243       0.270
# Niger                                0.366    0.318       0.188       0.102
# Gambia                               0.428    0.382       0.269       0.167
# Chad                                 0.192    0.174       0.198       0.078
# Comoros                              0.505    0.142       0.275       0.078
# Burundi                              0.380    0.220       0.176       0.180
# Haiti                                0.449    0.026       0.419       0.110
# Yemen                                0.463    0.143       0.108       0.077
# Rwanda                               0.614    0.555       0.217       0.411
# Central African Republic             0.105    0.225       0.235       0.035
# South Sudan                          0.295    0.010       0.202       0.091
#
#                          railways_per_capita
# countries
# Iceland                                  NaN
# Malta                                    NaN
# Qatar                                    NaN
# Bahrain                                  NaN
# Trinidad & Tobago                        NaN
# Nicaragua                                NaN
# Kosovo                                   NaN
# Cyprus                                   NaN
# Kuwait                                   NaN
# Mauritius                                NaN
# Northern Cyprus                          NaN
# Libya                                    NaN
# Lebanon                                  NaN
# Bhutan                                   NaN
# Palestinian Territories                  NaN
# Somalia                                  NaN
# Niger                                    NaN
# Gambia                                   NaN
# Chad                                     NaN
# Comoros                                  NaN
# Burundi                                  NaN
# Haiti                                    NaN
# Yemen                                    NaN
# Rwanda                                   NaN
# Central African Republic                 NaN
# South Sudan                              NaN

# %% [markdown]
# Actually missing from railways: Kosovo, Northern Cyprus, Congo (Brazzaville), Palestinian Territories, Comoros, Central African Republic, South Sudan. The rest is confirmed to have 0 railways. (see  in the [WB notebook](WB.ipynb))

# %% [markdown]
# ### lifeexp.csv

# %%
merge_and_check_empty('./data/lifeexp.csv', 'lifeexps')
# Out:
#                          happiness  GDP_per_capita  social_support  \
# countries
# Taiwan                       6.446           1.368           1.430
# Qatar                        6.374           1.684           1.313
# Kosovo                       6.100           0.882           1.232
# Estonia                      5.893           1.237           1.528
# Northern Cyprus              5.718           1.263           1.252
# Albania                      4.719           0.947           0.848
# Palestinian Territories      4.696           0.657           1.247
# Somalia                      4.668           0.000           0.698
#
#                          healthy_life_exp  freedom  generosity  corruption  \
# countries
# Taiwan                              0.914    0.351       0.242       0.097
# Qatar                               0.871    0.555       0.220       0.167
# Kosovo                              0.758    0.489       0.262       0.006
# Estonia                             0.874    0.495       0.103       0.161
# Northern Cyprus                     1.042    0.417       0.191       0.162
# Albania                             0.874    0.383       0.178       0.027
# Palestinian Territories             0.672    0.225       0.103       0.066
# Somalia                             0.268    0.559       0.243       0.270
#
#                          lifeexps
# countries
# Taiwan                        NaN
# Qatar                         NaN
# Kosovo                        NaN
# Estonia                       NaN
# Northern Cyprus               NaN
# Albania                       NaN
# Palestinian Territories       NaN
# Somalia                       NaN

# %% [markdown]
# Those countries don't have life expectancy data on Wikipedia

# %% [markdown]
# ## Section 2 - Merging All

# %% [markdown]
# In this section, we are merging all the csv files with the happiness file, and save everything in one combined csv.

# %%
list_of_csv_files = ['alcohol_consumption',
                     'cigarettes',
                     'economical_sectors',
                     'government_system',
                     'lifeexp',
                     'median_age',
                     'olympic_medals_2016',
                     'oscar',
                     'railways'
                    ]

# %%
df_combined = df_happiness.copy()

# %%
for file in list_of_csv_files:
    csv_filename = './data/' + file + '.csv'
    df = pd.read_csv(csv_filename)
    df = make_mergeable(df)
    df_combined = df_combined.join(df, how = 'left')

# %%
df_combined.head()
# Out:
#              happiness  GDP_per_capita  social_support  healthy_life_exp  \
# countries
# Finland          7.769           1.340           1.587             0.986
# Denmark          7.600           1.383           1.573             0.996
# Norway           7.554           1.488           1.582             1.028
# Iceland          7.494           1.380           1.624             1.026
# Netherlands      7.488           1.396           1.522             0.999
#
#              freedom  generosity  corruption  alcohol_consumption  \
# countries
# Finland        0.596       0.153       0.393                 12.3
# Denmark        0.592       0.252       0.410                 11.4
# Norway         0.603       0.271       0.341                  7.7
# Iceland        0.591       0.354       0.118                  7.1
# Netherlands    0.557       0.322       0.298                  9.9
#
#              cigarette_consumption agricultural  ... head_of_state lifeexps  \
# countries                                        ...
# Finland                     1098.8         2.7%  ...    Ceremonial     81.7
# Denmark                     1298.0         1.3%  ...    Ceremonial     80.8
# Norway                       552.8         2.3%  ...    Ceremonial     82.3
# Iceland                      848.1         5.8%  ...    Ceremonial     82.9
# Netherlands                 1459.9         1.6%  ...    Ceremonial     82.1
#
#             median_age median_age_male  median_age_female  gold_medals_2016  \
# countries
# Finland           42.5            40.9               44.3               0.0
# Denmark           42.2            41.2               43.2               2.0
# Norway            39.2            38.4               40.0               0.0
# Iceland           36.5            35.9               37.1               NaN
# Netherlands       42.6            41.5               43.6               8.0
#
#              silver_medals_2016  bronze_medals_2016  oscar_winning  \
# countries
# Finland                     0.0                 1.0            0.0
# Denmark                     6.0                 7.0            3.0
# Norway                      0.0                 4.0            0.0
# Iceland                     NaN                 NaN            0.0
# Netherlands                 7.0                 4.0            3.0
#
#              railways_per_capita
# countries
# Finland                      929
# Denmark                    2,893
# Norway                     1,350
# Iceland                      NaN
# Netherlands                5,591
#
# [5 rows x 23 columns]

# %%
df_combined.tail()
# Out:
#                           happiness  GDP_per_capita  social_support  \
# countries
# Rwanda                        3.334           0.359           0.711
# Tanzania                      3.231           0.476           0.885
# Afghanistan                   3.203           0.350           0.517
# Central African Republic      3.083           0.026           0.000
# South Sudan                   2.853           0.306           0.575
#
#                           healthy_life_exp  freedom  generosity  corruption  \
# countries
# Rwanda                               0.614    0.555       0.217       0.411
# Tanzania                             0.499    0.417       0.276       0.147
# Afghanistan                          0.361    0.000       0.158       0.025
# Central African Republic             0.105    0.225       0.235       0.035
# South Sudan                          0.295    0.010       0.202       0.091
#
#                           alcohol_consumption  cigarette_consumption  \
# countries
# Rwanda                                    9.8                   94.0
# Tanzania                                  7.7                  181.8
# Afghanistan                               0.7                  311.6
# Central African Republic                  3.8                  213.2
# South Sudan                               NaN                  383.7
#
#                          agricultural  ... head_of_state lifeexps median_age  \
# countries                              ...
# Rwanda                          30.9%  ...     Executive     68.7       19.0
# Tanzania                        23.4%  ...     Executive     65.0       17.7
# Afghanistan                     23.0%  ...     Executive     64.5       18.9
# Central African Republic        43.2%  ...     Executive     52.8       19.7
# South Sudan                       NaN  ...     Executive     57.6       17.3
#
#                          median_age_male  median_age_female  gold_medals_2016  \
# countries
# Rwanda                              18.3               19.8               NaN
# Tanzania                            17.5               18.0               NaN
# Afghanistan                         18.8               18.9               NaN
# Central African Republic            19.4               20.0               NaN
# South Sudan                         17.2               17.5               NaN
#
#                           silver_medals_2016  bronze_medals_2016  \
# countries
# Rwanda                                   NaN                 NaN
# Tanzania                                 NaN                 NaN
# Afghanistan                              NaN                 NaN
# Central African Republic                 NaN                 NaN
# South Sudan                              NaN                 NaN
#
#                           oscar_winning  railways_per_capita
# countries
# Rwanda                              NaN                  NaN
# Tanzania                            0.0               15,866
# Afghanistan                         0.0              418,827
# Central African Republic            NaN                  NaN
# South Sudan                         NaN                  NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# And as a final step, we are saving the combined DataFrame as a csv.

# %%
df_combined.to_csv('./data/combined_df.csv')
