# %% [markdown]
# # Getting data from the World Bank API

# %%
import pandas as pd
from pandas_datareader import wb

# %% [markdown]
# ## API exploration
# This API is actually implemented in pandas \o/
#
# But there are a **lot** of different variables and informations to deal with: 17328 different indicators

# %%
# Getting the variable ('id' field)
wb.get_indicators()
# Out:
#                                id  \
# 0              1.0.HCount.1.90usd
# 1               1.0.HCount.2.5usd
# 2            1.0.HCount.Mid10to50
# 3                 1.0.HCount.Ofcl
# 4             1.0.HCount.Poor4uds
# ...                           ...
# 17323    per_sionl.overlap_q1_tot
# 17324    per_sionl.overlap_q1_urb
# 17325                  s_loans_A1
# 17326     s_policyholders_B2_life
# 17327  s_policyholders_B2_nonlife
#
#                                                     name unit  \
# 0                        Poverty Headcount ($1.90 a day)
# 1                        Poverty Headcount ($2.50 a day)
# 2                  Middle Class ($10-50 a day) Headcount
# 3                Official Moderate Poverty Rate-National
# 4                           Poverty Headcount ($4 a day)
# ...                                                  ...  ...
# 17323  Population in the 1st quintile (poorest) only ...
# 17324  Population in the 1st quintile (poorest) only ...
# 17325                 Outstanding loans per 1,000 adults
# 17326   Insurance policy holders per 1,000 adults (life)
# 17327  Insurance policy holders per 1,000 adults (non...
#
#                                                   source  \
# 0                                         LAC Equity Lab
# 1                                         LAC Equity Lab
# 2                                         LAC Equity Lab
# 3                                         LAC Equity Lab
# 4                                         LAC Equity Lab
# ...                                                  ...
# 17323  The Atlas of Social Protection: Indicators of ...
# 17324  The Atlas of Social Protection: Indicators of ...
# 17325                 G20 Financial Inclusion Indicators
# 17326                 G20 Financial Inclusion Indicators
# 17327                 G20 Financial Inclusion Indicators
#
#                                               sourceNote  \
# 0      The poverty headcount index measures the propo...
# 1      The poverty headcount index measures the propo...
# 2      The poverty headcount index measures the propo...
# 3      The poverty headcount index measures the propo...
# 4      The poverty headcount index measures the propo...
# ...                                                  ...
# 17323                                               NULL
# 17324                                               NULL
# 17325
# 17326  Denotes the total number of life insurance pol...
# 17327  Denotes the total number of non-life insurance...
#
#                                       sourceOrganization  \
# 0      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...
# 1      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...
# 2      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...
# 3      b'LAC Equity Lab tabulations of data from Nati...
# 4      b'LAC Equity Lab tabulations of SEDLAC (CEDLAS...
# ...                                                  ...
# 17323  b'The Atlas of Social Protection: Indicators o...
# 17324  b'The Atlas of Social Protection: Indicators o...
# 17325                                                b''
# 17326  b'International Monetary Fund, Financial Acces...
# 17327  b'International Monetary Fund, Financial Acces...
#
#                           topics
# 0                       Poverty
# 1                       Poverty
# 2                       Poverty
# 3                       Poverty
# 4                       Poverty
# ...                          ...
# 17323  Social Protection & Labor
# 17324  Social Protection & Labor
# 17325
# 17326
# 17327
#
# [17328 rows x 7 columns]

# %%
# Searching for variables
wb.search('alcohol')
# Out:
#                       id                                               name  \
# 10711  SH.ALC.PCAP.FE.LI  Total alcohol consumption per capita, female (...
# 10712     SH.ALC.PCAP.LI  Total alcohol consumption per capita (liters o...
# 10713  SH.ALC.PCAP.MA.LI  Total alcohol consumption per capita, male (li...
#
#       unit                        source  \
# 10711       World Development Indicators
# 10712       World Development Indicators
# 10713       World Development Indicators
#
#                                               sourceNote  \
# 10711  Total alcohol per capita consumption is define...
# 10712  Total alcohol per capita consumption is define...
# 10713  Total alcohol per capita consumption is define...
#
#                                       sourceOrganization   topics
# 10711  b'World Health Organization, Global Health Obs...  Health
# 10712  b'World Health Organization, Global Health Obs...  Health
# 10713  b'World Health Organization, Global Health Obs...  Health

# %%
# Getting the list of countries
wb.get_countries().head(1)
# Out:
#   iso3c iso2c   name                      region adminregion  incomeLevel  \
# 0   ABW    AW  Aruba  Latin America & Caribbean               High income
#
#       lendingType capitalCity  longitude  latitude
# 0  Not classified  Oranjestad   -70.0167   12.5167

# %% [markdown]
# ## Getting ready to process the files
#
# As these variables will be added to the data gathered from the [Wikipedia webscraping](wiki_data_combine.ipynb), we need to format it so it merges:

# %%
country_rename_dict = {"China, People's Republic of" : "China",
                       "Cote d'Ivoire" : "Ivory Coast",
                       "Côte d'Ivoire" : "Ivory Coast",
                       "People's Republic of China" : "China",
                       'Burma' : 'Myanmar',
                       'Congo' : 'Congo (Brazzaville)',
                       'Congo, Dem. Rep.' : 'Congo (Kinshasa)',
                       'Congo, Democratic Republic of the' : 'Congo (Kinshasa)',
                       'Congo, Rep.' : 'Congo (Brazzaville)',
                       'Congo, Republic of the' : 'Congo (Brazzaville)',
                       'Congo, Republic of' : 'Congo (Brazzaville)',
                       'Czech Republic' : 'Czechia',
                       'Democratic Republic of Congo' : 'Congo (Kinshasa)',
                       'Democratic Republic of the Congo' : 'Congo (Kinshasa)',
                       'DR Congo' : 'Congo (Kinshasa)',
                       'Egypt, Arab Rep.' : 'Egypt',
                       'Eswatini (Swaziland)' : 'Eswatini',
                       'Gambia, The' : 'Gambia',
                       'Great Britain': 'United Kingdom',
                       'Hong Kong SAR, China' : 'Hong Kong',
                       'Iran, Islamic Rep.' : 'Iran',
                       'Korea, North' : 'North Korea',
                       'Korea, Rep.' : 'South Korea',
                       'Korea, South' : 'South Korea',
                       'Kyrgyz Republic' : 'Kyrgyzstan',
                       'Lao PDR' : 'Laos',
                       'Republic of the Congo' : 'Congo (Brazzaville)',
                       'Russian Federation' : 'Russia',
                       'Swaziland' : 'Eswatini',
                       'Slovak Republic' : 'Slovakia',
                       'The Gambia' : 'Gambia',
                       'Trinidad and Tobago' : 'Trinidad & Tobago',
                       'United States' : 'United States of America',
                       'Venezuela, RB' : 'Venezuela',
                       'Yemen, Rep.' : 'Yemen'
                      }

# %%
def rename_country(country_name):
    if country_name in country_rename_dict.keys():
        return country_rename_dict[country_name]
    else:
        return country_name
    
def table_mod(table):
    '''
    Modifying the table so it has a 'countries' column (necessary for merging it to the existing DataFrame)
    And getting the same spelling for countries, using the 'country_rename_dict'
    '''
    table['country'] = table['country'].apply(lambda x: rename_country(x))
    table.rename(columns={'country':'countries'}, inplace=True)
    table.set_index('countries', inplace = True)
    return table

# %% [markdown]
# ## Country list
#
# Has some categorical information about the countries, such as low/med/high income, etc.

# %%
countries = wb.get_countries()
countries.rename(columns={'name':'country'}, inplace=True)
countries
# Out:
#     iso3c iso2c                                            country  \
# 0     ABW    AW                                              Aruba
# 1     AFG    AF                                        Afghanistan
# 2     AFR    A9                                             Africa
# 3     AGO    AO                                             Angola
# 4     ALB    AL                                            Albania
# ..    ...   ...                                                ...
# 299   XZN    A5  Sub-Saharan Africa excluding South Africa and ...
# 300   YEM    YE                                        Yemen, Rep.
# 301   ZAF    ZA                                       South Africa
# 302   ZMB    ZM                                             Zambia
# 303   ZWE    ZW                                           Zimbabwe
#
#                          region  \
# 0    Latin America & Caribbean
# 1                    South Asia
# 2                    Aggregates
# 3           Sub-Saharan Africa
# 4         Europe & Central Asia
# ..                          ...
# 299                  Aggregates
# 300  Middle East & North Africa
# 301         Sub-Saharan Africa
# 302         Sub-Saharan Africa
# 303         Sub-Saharan Africa
#
#                                            adminregion          incomeLevel  \
# 0                                                               High income
# 1                                           South Asia           Low income
# 2                                                                Aggregates
# 3           Sub-Saharan Africa (excluding high income)  Lower middle income
# 4        Europe & Central Asia (excluding high income)  Upper middle income
# ..                                                 ...                  ...
# 299                                                              Aggregates
# 300  Middle East & North Africa (excluding high inc...           Low income
# 301         Sub-Saharan Africa (excluding high income)  Upper middle income
# 302         Sub-Saharan Africa (excluding high income)  Lower middle income
# 303         Sub-Saharan Africa (excluding high income)  Lower middle income
#
#         lendingType capitalCity  longitude  latitude
# 0    Not classified  Oranjestad   -70.0167  12.51670
# 1               IDA       Kabul    69.1761  34.52280
# 2        Aggregates                    NaN       NaN
# 3              IBRD      Luanda    13.2420  -8.81155
# 4              IBRD      Tirane    19.8172  41.33170
# ..              ...         ...        ...       ...
# 299      Aggregates                    NaN       NaN
# 300             IDA      Sana'a    44.2075  15.35200
# 301            IBRD    Pretoria    28.1871 -25.74600
# 302             IDA      Lusaka    28.2937 -15.39820
# 303           Blend      Harare    31.0672 -17.83120
#
# [304 rows x 10 columns]

# %%
countries.to_csv('./data/Countries.csv')

# %% [markdown]
# ## Internet access
#
# Has information about the population access to internet, contains some age categories (15-34,35-59,60+)

# %%
df = wb.search('access to internet')

# %%
internet = wb.download(indicator=[i for i in df['id']],country='all',start=2017,end=2017)
internet.columns = [title for title in df['name']]
internet
# Out:
#                             Access to internet (% age 15+)  \
# country               year
# Afghanistan           2017                        14.80909
# Albania               2017                        47.62765
# Algeria               2017                        56.46716
# American Samoa        2017                             NaN
# Andorra               2017                             NaN
# ...                                                    ...
# Virgin Islands (U.S.) 2017                             NaN
# West Bank and Gaza    2017                        55.03128
# Yemen, Rep.           2017                             NaN
# Zambia                2017                        25.41447
# Zimbabwe              2017                        32.38422
#
#                             Access to internet, female (% age 15+)  \
# country               year
# Afghanistan           2017                                4.882765
# Albania               2017                               44.803910
# Algeria               2017                               52.998200
# American Samoa        2017                                     NaN
# Andorra               2017                                     NaN
# ...                                                            ...
# Virgin Islands (U.S.) 2017                                     NaN
# West Bank and Gaza    2017                               53.860550
# Yemen, Rep.           2017                                     NaN
# Zambia                2017                               20.395380
# Zimbabwe              2017                               23.320360
#
#                             Access to internet, male (% age 15+)  \
# country               year
# Afghanistan           2017                              24.62060
# Albania               2017                              50.62286
# Algeria               2017                              59.92853
# American Samoa        2017                                   NaN
# Andorra               2017                                   NaN
# ...                                                          ...
# Virgin Islands (U.S.) 2017                                   NaN
# West Bank and Gaza    2017                              56.24088
# Yemen, Rep.           2017                                   NaN
# Zambia                2017                              30.64323
# Zimbabwe              2017                              42.25463
#
#                             Access to internet, income, poorest 40% (% age 15+)  \
# country               year
# Afghanistan           2017                                           9.009466
# Albania               2017                                          34.689220
# Algeria               2017                                          42.665030
# American Samoa        2017                                                NaN
# Andorra               2017                                                NaN
# ...                                                                       ...
# Virgin Islands (U.S.) 2017                                                NaN
# West Bank and Gaza    2017                                          30.812310
# Yemen, Rep.           2017                                                NaN
# Zambia                2017                                          12.752460
# Zimbabwe              2017                                          14.543730
#
#                             Access to internet, income, richest 60% (% age 15+)  \
# country               year
# Afghanistan           2017                                           18.66901
# Albania               2017                                           56.23954
# Algeria               2017                                           65.64495
# American Samoa        2017                                                NaN
# Andorra               2017                                                NaN
# ...                                                                       ...
# Virgin Islands (U.S.) 2017                                                NaN
# West Bank and Gaza    2017                                           71.13063
# Yemen, Rep.           2017                                                NaN
# Zambia                2017                                           33.85024
# Zimbabwe              2017                                           44.25152
#
#                             Access to internet (% ages 15-34)  \
# country               year
# Afghanistan           2017                           18.33455
# Albania               2017                           75.53036
# Algeria               2017                           69.20241
# American Samoa        2017                                NaN
# Andorra               2017                                NaN
# ...                                                       ...
# Virgin Islands (U.S.) 2017                                NaN
# West Bank and Gaza    2017                           60.99529
# Yemen, Rep.           2017                                NaN
# Zambia                2017                           30.59592
# Zimbabwe              2017                           38.67941
#
#                             Access to internet (% ages 35-59)  \
# country               year
# Afghanistan           2017                           9.081439
# Albania               2017                          37.041380
# Algeria               2017                          44.924090
# American Samoa        2017                                NaN
# Andorra               2017                                NaN
# ...                                                       ...
# Virgin Islands (U.S.) 2017                                NaN
# West Bank and Gaza    2017                          50.841650
# Yemen, Rep.           2017                                NaN
# Zambia                2017                          18.029440
# Zimbabwe              2017                          27.082170
#
#                             Access to internet (% age 60+)
# country               year
# Afghanistan           2017                        7.316440
# Albania               2017                       17.318520
# Algeria               2017                       27.347940
# American Samoa        2017                             NaN
# Andorra               2017                             NaN
# ...                                                    ...
# Virgin Islands (U.S.) 2017                             NaN
# West Bank and Gaza    2017                       29.335640
# Yemen, Rep.           2017                             NaN
# Zambia                2017                        8.907472
# Zimbabwe              2017                        4.095412
#
# [217 rows x 8 columns]

# %%
internet.to_csv('./data/Access_to_internet.csv')

# %% [markdown]
# ## GDP (cross-referencing with Wikipedia)
#
# Has information about the GDP per capita, in current USD. Conveniently, it is the one used on Wikipedia

# %%
gdp = wb.search('GDP per capita')

# %%
df = wb.download(indicator=['NY.GDP.PCAP.CD'],country='all',start=2018,end=2019)
df.columns = gdp[gdp['id']=='NY.GDP.PCAP.CD']['name']
df = df.dropna()

# %%
df.to_csv('./data/GDP.csv')

# %% [markdown]
# ## Suicide
#
# Has information about suicide rates: Male, Female and Global

# %%
suicide = wb.search('suicide')

# %%
df = wb.download(indicator=['SH.STA.SUIC.FE.P5','SH.STA.SUIC.MA.P5','SH.STA.SUIC.P5'],country='all',start=2016,end=2016)
df.columns = [title for title in suicide['name']]
df
# Out:
#                                      Suicide mortality rate, female (per 100,000 female population)  \
# country                        year
# Arab World                     2016                                           2.445834
# Caribbean small states         2016                                           3.906739
# Central Europe and the Baltics 2016                                           5.155971
# Early-demographic dividend     2016                                           8.066567
# East Asia & Pacific            2016                                           8.411334
# ...                                                                                ...
# Virgin Islands (U.S.)          2016                                                NaN
# West Bank and Gaza             2016                                                NaN
# Yemen, Rep.                    2016                                           5.600000
# Zambia                         2016                                           3.500000
# Zimbabwe                       2016                                           6.000000
#
#                                      Suicide mortality rate, male (per 100,000 male population)  \
# country                        year
# Arab World                     2016                                           5.953132
# Caribbean small states         2016                                          14.327918
# Central Europe and the Baltics 2016                                          25.854199
# Early-demographic dividend     2016                                          11.719699
# East Asia & Pacific            2016                                          10.562305
# ...                                                                                ...
# Virgin Islands (U.S.)          2016                                                NaN
# West Bank and Gaza             2016                                                NaN
# Yemen, Rep.                    2016                                          11.300000
# Zambia                         2016                                           8.800000
# Zimbabwe                       2016                                          15.700000
#
#                                      Suicide mortality rate (per 100,000 population)
# country                        year
# Arab World                     2016                                         4.271912
# Caribbean small states         2016                                         9.100475
# Central Europe and the Baltics 2016                                        15.157308
# Early-demographic dividend     2016                                         9.935441
# East Asia & Pacific            2016                                         9.508817
# ...                                                                              ...
# Virgin Islands (U.S.)          2016                                              NaN
# West Bank and Gaza             2016                                              NaN
# Yemen, Rep.                    2016                                         8.500000
# Zambia                         2016                                         6.100000
# Zimbabwe                       2016                                        10.700000
#
# [264 rows x 3 columns]

# %%
df.to_csv('./data/Suicide.csv')

# %% [markdown]
# # Creating the master dataframe
#
# Now that our files have been created, we import data from those csv, drop a few columns and readjust the index so it all can be added to the DataFrame we will use for our analysis.
#
# We went throught the hassle of creating/importing csv files as it is more robust and faster when resuming work on the project (especially when pair programming) but these steps are not required, we could have created a database instead.

# %%
# Importing the csv
combined = pd.read_csv('./data/combined_df.csv')

continents = pd.read_csv('./data/continents.csv')
del continents['iso3c']

countries = pd.read_csv('./data/Countries.csv',index_col=0)

gdp = pd.read_csv('./data/GDP.csv',)
del gdp['year']

internet = pd.read_csv('./data/Access_to_internet.csv')
del internet['year']

suicide = pd.read_csv('./data/Suicide.csv')
del suicide['year']

# %%
# Merging into a master table, we could refactor as a function or even a class

table_mod(gdp)
df_combined = combined.join(gdp,on='countries',how='left')

table_mod(suicide)
df_combined = df_combined.join(suicide,on='countries',how='left')

table_mod(countries)
df_combined = df_combined.join(countries,on='countries',how='left')

table_mod(internet)
df_combined = df_combined.join(internet,on='countries',how='left')

table_mod(continents)
df_combined = df_combined.join(continents,on='countries',how='left')

# %%
df_combined
# Out:
#                     countries  happiness  GDP_per_capita  social_support  \
# 0                     Finland      7.769           1.340           1.587
# 1                     Denmark      7.600           1.383           1.573
# 2                      Norway      7.554           1.488           1.582
# 3                     Iceland      7.494           1.380           1.624
# 4                 Netherlands      7.488           1.396           1.522
# ..                        ...        ...             ...             ...
# 151                    Rwanda      3.334           0.359           0.711
# 152                  Tanzania      3.231           0.476           0.885
# 153               Afghanistan      3.203           0.350           0.517
# 154  Central African Republic      3.083           0.026           0.000
# 155               South Sudan      2.853           0.306           0.575
#
#      healthy_life_exp  freedom  generosity  corruption  alcohol_consumption  \
# 0               0.986    0.596       0.153       0.393                 12.3
# 1               0.996    0.592       0.252       0.410                 11.4
# 2               1.028    0.603       0.271       0.341                  7.7
# 3               1.026    0.591       0.354       0.118                  7.1
# 4               0.999    0.557       0.322       0.298                  9.9
# ..                ...      ...         ...         ...                  ...
# 151             0.614    0.555       0.217       0.411                  9.8
# 152             0.499    0.417       0.276       0.147                  7.7
# 153             0.361    0.000       0.158       0.025                  0.7
# 154             0.105    0.225       0.235       0.035                  3.8
# 155             0.295    0.010       0.202       0.091                  NaN
#
#      cigarette_consumption  ...  latitude Access to internet (% age 15+)  \
# 0                   1098.8  ...  60.16080                      91.492410
# 1                   1298.0  ...  55.67630                      92.331520
# 2                    552.8  ...  59.91380                      95.795970
# 3                    848.1  ...  64.13530                            NaN
# 4                   1459.9  ...  52.37380                      91.965280
# ..                     ...  ...       ...                            ...
# 151                   94.0  ...  -1.95325                      11.482790
# 152                  181.8  ...  -6.17486                      18.970620
# 153                  311.6  ...  34.52280                      14.809090
# 154                  213.2  ...   5.63056                       7.161354
# 155                  383.7  ...   4.85000                       4.063704
#
#     Access to internet, female (% age 15+)  \
# 0                                88.838040
# 1                                89.203510
# 2                                95.889020
# 3                                      NaN
# 4                                90.310570
# ..                                     ...
# 151                               8.280919
# 152                              13.864560
# 153                               4.882765
# 154                               4.901110
# 155                               1.636335
#
#     Access to internet, male (% age 15+)  \
# 0                              94.352520
# 1                              95.526910
# 2                              95.703790
# 3                                    NaN
# 4                              93.652470
# ..                                   ...
# 151                            15.106390
# 152                            24.301670
# 153                            24.620600
# 154                             9.594541
# 155                             6.536037
#
#     Access to internet, income, poorest 40% (% age 15+)  \
# 0                                            86.586430
# 1                                            88.256040
# 2                                            94.078900
# 3                                                  NaN
# 4                                            92.005390
# ..                                                 ...
# 151                                           5.251483
# 152                                          10.125620
# 153                                           9.009466
# 154                                           3.569112
# 155                                           2.027439
#
#      Access to internet, income, richest 60% (% age 15+)  \
# 0                                            94.761090
# 1                                            95.045990
# 2                                            96.939320
# 3                                                  NaN
# 4                                            91.938610
# ..                                                 ...
# 151                                          15.635840
# 152                                          24.826540
# 153                                          18.669010
# 154                                           9.546126
# 155                                           5.420220
#
#      Access to internet (% ages 15-34)  Access to internet (% ages 35-59)  \
# 0                            99.264210                          97.733920
# 1                            99.494810                          98.093170
# 2                           100.000000                          97.917570
# 3                                  NaN                                NaN
# 4                           100.000000                          96.294080
# ..                                 ...                                ...
# 151                          16.327590                           4.351039
# 152                          25.424040                          11.978890
# 153                          18.334550                           9.081439
# 154                           9.016120                           5.594250
# 155                           5.819171                           1.614446
#
#      Access to internet (% age 60+)  continent
# 0                         78.803990     Europe
# 1                         77.035940     Europe
# 2                         88.694240     Europe
# 3                               NaN     Europe
# 4                         77.611290     Europe
# ..                              ...        ...
# 151                        1.870723     Africa
# 152                        2.366465     Africa
# 153                        7.316440       Asia
# 154                        0.000000     Africa
# 155                        0.000000     Africa
#
# [156 rows x 46 columns]

# %% [markdown]
# ## Cleaning the data

# %%
# Rename some columns
df_combined.rename(columns = {'countries': 'country',
                              'lifeexps': 'life_expectancy',
                              'railways_per_capita': 'population_per_railways_km'
                             }, inplace = True);

# %%
# Populate missing with 0's where it makes sense
list_of_columns = ['gold_medals_2016',
                   'silver_medals_2016',
                   'bronze_medals_2016',
                   'oscar_winning'
                  ]
for column in list_of_columns:
    df_combined[column] = df_combined[column].fillna(0)

# %%
# Delete countries that are missing from lot of columns
list_of_countries_to_drop = ['Kosovo',
                             'Northern Cyprus',
                             'Palestinian Territories',
                             'South Sudan',
                            ]
for country in list_of_countries_to_drop:
    df_combined = df_combined[df_combined.country != country]

# %%
# Adjusting sectors and railways, they are not numbers.
df_combined['agricultural'] = df_combined['agricultural'].apply(lambda x: float(str(x)[:-1]))
df_combined['industrial'] = df_combined['industrial'].apply(lambda x: float(str(x)[:-1]))
df_combined['service'] = df_combined['service'].apply(lambda x: float(str(x)[:-1]))

# %%
def remove_comma(string):
    """
    Removes comma from string, input could be a float as well in which case don't touch it. 
    """
    if type(string) == str:
        string = string.replace(',', '')
        
    return string

# %%
df_combined['population_per_railways_km'] = df_combined['population_per_railways_km'].apply(lambda x: float(remove_comma(x)))

# %%
df_combined.to_csv('./data/finaldf.csv')
